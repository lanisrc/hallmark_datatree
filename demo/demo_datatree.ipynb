# %%
from pathlib import Path
from hallmark.eht_datatree import build_tree
import pandas as pd
pd.set_option("display.width", 200)
pd.set_option("display.max_columns", None)

# %%
root = Path("~/EHTC_SgrAmwl2017_May2022").expanduser()
tree = build_tree(root, [
    "sgra_{date}_{telescope}",
    "sgra_{date}_{telescope}_{variant}",
])
print("tree keys:", list(tree.keys()))
print(list(tree["data"].keys()))

# %%
print("=== META ===")
print(tree["meta"])

# %%
print("=== DRIVES ===")
print(tree["drives"])

# %%
print("=== DATA STEMS ===")
for stem in tree["data"].keys():
    print(f"  {stem}")

# %%
print("=== ONE STEM ===")
print(tree["data"]["20170411_chandra_bb.csv"])
